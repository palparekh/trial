# %% [markdown]
# ---
# # Computing Aggregate Statistics

# %%
import pandas as pd

names = ['Bob','Jessica','Mary','John','Mel']
grades = [76,95,77,78,99]

GradeList = list(zip(names,grades))
df = pd.DataFrame(data = GradeList, columns=['Names', 'Grades'])
df
# Out:
#      Names  Grades
# 0      Bob      76
# 1  Jessica      95
# 2     Mary      77
# 3     John      78
# 4      Mel      99

# %%
df['Grades'].count() # computes the number of valuesf['Grades'].count() # computes the number of values

df['Grades'].mean() # computes the arithmetic average of the values

df['Grades'].std() # computes the standard deviation of the values

df['Grades'].min() # computes the minimum of the values
df['Grades'].max() # computes the maximum of the values

df['Grades'].quantile(.25) # computes the first quartile of the values
df['Grades'].quantile(.5) # computes the second quartile of the values
df['Grades'].quantile(.75) # computes the third quartile of the values
# Out:
# 95.0

# %%
df['Grades'].count()
# Out:
# 5

# %% [markdown]
# ### Note
# If you tried to execute the previous code in one cell all at the same time, the only thing you will see is the output of the .quantile() function. You have to try them one by one. I just grouped them all together for reference purposes. OK?

# %% [markdown]
# ### Other Measures of Central Tendency

# %%
# computes the arithmetic average of the values in a column
# mean = dividing the sum of all values by the number of values
df['Grades'].mean()

# finds the median of the values in a column
# median = the middle value if they are sorted in order
df['Grades'].median()

# finds the mode of the values in a column
# mode = the most common single value
df['Grades'].mode()
# Out:
# 0    76
# 1    77
# 2    78
# 3    95
# 4    99
# dtype: int64

# %%
df['Grades'].median()
# Out:
# 78.0

# %%
df['Grades'].mean()
# Out:
# 85.0

# %%
df['Grades'].mode()
# Out:
# 0    76
# 1    77
# 2    78
# 3    95
# 4    99
# dtype: int64

# %%
df['Grades'].var()
# Out:
# 122.5

# %%
df.var()
# Out:
# Grades    122.5
# dtype: float64

# %% [markdown]
# ### Your Turn
# Of course, in our dataset we only have one column. Try creating a dataframe and computing summary statistics using the following dataset.

# %%
import pandas as pd
names = ['Bob','Jessica','Mary','John','Mel']
grades = [76,95,77,78,99]
bsdegrees = [1,1,0,0,1]
msdegrees = [2,1,0,0,0]
phddegrees = [0,1,0,0,0]
Degrees = list(zip(names,grades,bsdegrees,msdegrees,phddegrees))
df = pd.DataFrame(data = Degrees, columns=['Names', 'Grades','bsdegrees','msdegrees','phddegrees'])
df
# Out:
#      Names  Grades  bsdegrees  msdegrees  phddegrees
# 0      Bob      76          1          2           0
# 1  Jessica      95          1          1           1
# 2     Mary      77          0          0           0
# 3     John      78          0          0           0
# 4      Mel      99          1          0           0

# %%
df['Grades'].median()
df ['bsdegrees'].median()
df['bsdegrees'].mode()
# Out:
# 0    1
# dtype: int64

# %% [markdown]
# ---
# # Computing Aggregate Statistics on Matching Rows

# %%
import pandas as pd

names = ['Bob','Jessica','Mary','John','Mel']
grades = [76,95,77,78,99]
bsdegrees = [1,1,0,0,1]
msdegrees = [2,1,0,0,0]
phddegrees = [0,1,0,0,0]

GradeList = list(zip(names,grades,bsdegrees,msdegrees,phddegrees))

df = pd.DataFrame(data=GradeList, columns=['Name','Grade','BS','MS','PhD'])
df
# Out:
#       Name  Grade  BS  MS  PhD
# 0      Bob     76   1   2    0
# 1  Jessica     95   1   1    1
# 2     Mary     77   0   0    0
# 3     John     78   0   0    0
# 4      Mel     99   1   0    0

# %%
df[df['PhD']==0].count()
# Out:
# Name     4
# Grade    4
# BS       4
# MS       4
# PhD      4
# dtype: int64

# %%
df.loc[df['PhD']==0]['Grade'].mean()
# Out:
# 82.5

# %% [markdown]
# ### Your Turn
# Using the following data, what is the average grade for people with MS degrees?

# %%
import pandas as pd
  
names = ['Bob','Jessica','Mary','John','Mel','Sam','Cathy','Henry','Lloyd']
grades = [76,95,77,78,99,84,79,100,73]
bsdegrees = [1,1,0,0,1,1,1,0,1]
msdegrees = [2,1,0,0,0,1,1,0,0]
phddegrees = [0,1,0,0,0,2,1,0,0]
Degrees = list(zip(names,grades,bsdegrees,msdegrees,phddegrees))
columns=['Names','Grades','BS','MS','PhD']
df = pd.DataFrame(data=Degrees, columns=columns)
df.head()
df.loc[df['MS']==1]['Grades'].mean()
# Out:
# 86.0

# %% [markdown]
# ---
# # Sorting Data

# %%
import pandas as pd

Location = "gradedata.csv"
df = pd.read_csv(Location)

df.head()

# %%
import pandas as pd

Location = "gradedata.csv"
df = pd.read_csv(Location)
df = df.sort_values(by='age', ascending=0)
df.head()
# Out:
#         fname      lname  gender  age  exercise  hours  grade  \
# 1000    Hanna     Mooney  female   19         2     10   88.8
# 902    Steven     Graham    male   19         4     17   95.1
# 818   Colette      Rojas  female   19         4      6   73.3
# 822     Rinah   Jacobson  female   19         1      7   80.8
# 826     Hayes  Wilkinson    male   19         5      3   76.0
#
#                                          address
# 1000  8293 SW. Cedar Swamp Lane, Union, NJ 07083
# 902                90 Grove St., Camas, WA 98607
# 818      17 Pin Oak Street, Villa Park, IL 60181
# 822       737 Amherst Court, Amsterdam, NY 12010
# 826       350 Temple Court, Mason City, IA 50401

# %%
df = df.sort_values(by=['grade', 'age'], ascending=[True, True])
df.head()
# Out:
#        fname      lname  gender  age  exercise  hours  grade  \
# 664    Alika      Poole  female   19         2     16   32.0
# 972   Keegan  Rasmussen    male   19         4      3   43.0
# 1870    Levi    Coleman    male   19         3      3   55.9
# 1910    Gail     Mcneil  female   17         2      3   56.1
# 1494   Jenna     Wagner  female   16         1      3   56.3
#
#                                             address
# 664     9282 Purple Finch Lane, Lexington, NC 27292
# 972   876 East Pilgrim Street, Chelmsford, MA 01824
# 1870      9453 Laurel Street, Jersey City, NJ 07302
# 1910            8409A Spruce St., Fishers, IN 46037
# 1494    8829 Shore Dr., Hopewell Junction, NY 12533

# %% [markdown]
# ### Your Turn
# Can you sort the dataframe to order it by name, age and then grade?

# %% [markdown]
# ---
# # Correlation

# %%
import pandas as pd

Location = "gradedata.csv"
df = pd.read_csv(Location)

df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
df.corr()
# Out:
#                age  exercise     hours     grade
# age       1.000000 -0.003643 -0.017467 -0.007580
# exercise -0.003643  1.000000  0.021105  0.161286
# hours    -0.017467  0.021105  1.000000  0.801955
# grade    -0.007580  0.161286  0.801955  1.000000

# %% [markdown]
# ### Your Turn
# Load the data in the following code and find the correlations:

# %%
import pandas as pd
 
Location = "tamiami.csv"
df = pd.read_csv(Location)

df.head()
df.corr()
# Out:
#                                       Cart Location  Hot Dog Sales  \
# Cart Location                              1.000000       0.042705
# Hot Dog Sales                              0.042705       1.000000
# Employees in Nearby Office Buildings      -0.068923       0.943238
# Num of Nearby Restaurants                  0.049701       0.913674
# Num of Other Food Carts Nearby             0.077219      -0.919762
# Price                                     -0.138444      -0.966378
#
#                                       Employees in Nearby Office Buildings  \
# Cart Location                                                    -0.068923
# Hot Dog Sales                                                     0.943238
# Employees in Nearby Office Buildings                              1.000000
# Num of Nearby Restaurants                                         0.856976
# Num of Other Food Carts Nearby                                   -0.874692
# ...

# %% [markdown]
# ---
# # Regression

# %%
import pandas as pd

Location = "gradedata.csv"
df = pd.read_csv(Location)

df.head()

# %%
import pandas as pd

Location = "gradedata.csv"
df = pd.read_csv(Location)

df.head()
import statsmodels.formula.api as sm
result = sm.ols(formula='grade ~ age + exercise + hours', data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  grade   R-squared:                       0.664
# Model:                            OLS   Adj. R-squared:                  0.664
# Method:                 Least Squares   F-statistic:                     1315.
# Date:                Fri, 23 Feb 2018   Prob (F-statistic):               0.00
# Time:                        21:19:45   Log-Likelihood:                -6300.7
# No. Observations:                2000   AIC:                         1.261e+04
# Df Residuals:                    1996   BIC:                         1.263e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     57.8704      1.321     43.804      0.000        55.279    60.461
# ...

# %%
import statsmodels.formula.api as sm
result = sm.ols(formula='grade ~ exercise + hours', data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  grade   R-squared:                       0.664
# Model:                            OLS   Adj. R-squared:                  0.664
# Method:                 Least Squares   F-statistic:                     1973.
# Date:                Fri, 23 Feb 2018   Prob (F-statistic):               0.00
# Time:                        21:22:10   Log-Likelihood:                -6300.8
# No. Observations:                2000   AIC:                         1.261e+04
# Df Residuals:                    1997   BIC:                         1.262e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     58.5316      0.447    130.828      0.000        57.654    59.409
# ...

# %%
import pandas as pd

Location = "gradedata.csv"
df = pd.read_csv(Location)

df.head()

result = sm.ols(formula='grade ~ age + exercise + hours - 1', data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  grade   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                 7.284e+04
# Date:                Fri, 23 Feb 2018   Prob (F-statistic):               0.00
# Time:                        21:58:37   Log-Likelihood:                -6974.3
# No. Observations:                2000   AIC:                         1.395e+04
# Df Residuals:                    1997   BIC:                         1.397e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# age            3.1129      0.035     88.030      0.000         3.044     3.182
# ...

# %% [markdown]
# ### Your Turn
# Create a new column where you convert gender to numeric values like 1 for female and 0 for male. Can you now add gender to your regression? Does this improve your R-squared?

# %%
import pandas as pd

Location = "gradedata.csv"
df = pd.read_csv(Location)

df.head()
def score_to_numeric(x):
    if x=='female':
        return 1
    if x=='male':
        return 0
df['gender_value']=df['gender'].apply(score_to_numeric)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address  gender_value
# 0   9253 Richardson Road, Matawan, NJ 07747             1
# 1          33 Spring Dr., Taunton, MA 02780             0
# 2          41 Hill Avenue, Mentor, OH 44060             0
# 3        8839 Marshall St., Miami, FL 33125             1
# 4  8304 Charles Rd., Lewis Center, OH 43035             1

# %%
import statsmodels.formula.api as sm
result = sm.ols(formula='grade ~ gender + exercise + hours', data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  grade   R-squared:                       0.665
# Model:                            OLS   Adj. R-squared:                  0.664
# Method:                 Least Squares   F-statistic:                     1318.
# Date:                Fri, 23 Feb 2018   Prob (F-statistic):               0.00
# Time:                        21:59:28   Log-Likelihood:                -6299.3
# No. Observations:                2000   AIC:                         1.261e+04
# Df Residuals:                    1996   BIC:                         1.263e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# ...

# %%
## titanic 3 exercise
import pandas as pd
import numpy as np
Location = "titanic3.xls"
df = pd.read_excel(Location)
def score_to_numeric(x):
    if x=='female':
        return 1
    if x=='male':
        return 0
df['gender_value']=df['sex'].apply(score_to_numeric)
df['has family'] = np.where((df['sibsp']<1) & (df['parch'] <1),0,1)
df.drop(['sibsp','parch'], axis=1)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
# ...

# %%
import pandas as pd
import numpy as np
Location = "titanic3.xls"
df = pd.read_excel(Location)
df_nobody = df['body'].isnull()
df[df_nobody]
df_noboat = df['boat'].isnull()
df_live = df['survived']==1
df['status'] = np.where ((df_nobody & df_noboat),0,1)
df.loc[df['survived']>0,'status']=2
df.head()
df_steerage = df['cabin'].isnull()
df['accomodation'] = np.where ((df_steerage),0,1)
df.head()
def score_to_numeric(x):
    if x=='female':
        return 1
    if x=='male':
        return 0
df['gender_value']=df['sex'].apply(score_to_numeric)
df['has family'] = np.where((df['sibsp']<1) & (df['parch'] <1),0,1)
df.drop(['sibsp','parch','cabin','boat','body'], axis=1)
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
import pandas as pd
import numpy as np
Location = "titanic3.xls"
df = pd.read_excel(Location)
df_nobody = df['body'].isnull()
df[df_nobody]
df_noboat = df['boat'].isnull()
df_live = df['survived']==1
df['status'] = np.where ((df_nobody & df_noboat),0,1)
df.loc[df['survived']>0,'status']=2
df.head()
df_steerage = df['cabin'].isnull()
df['accomodation'] = np.where ((df_steerage),0,1)
df.head()
def score_to_numeric(x):
    if x=='female':
        return 1
    if x=='male':
        return 0
df['gender_value']=df['sex'].apply(score_to_numeric)
df['has family'] = np.where((df['sibsp']<1) & (df['parch'] <1),0,1)
df.drop(['sibsp','parch','cabin','boat','body'], axis=1)
df.corr()
# Out:
#                 pclass  survived       age     sibsp     parch      fare  \
# pclass        1.000000 -0.312469 -0.408106  0.060832  0.018322 -0.558629
# survived     -0.312469  1.000000 -0.055513 -0.027825  0.082660  0.244265
# age          -0.408106 -0.055513  1.000000 -0.243699 -0.150917  0.178739
# sibsp         0.060832 -0.027825 -0.243699  1.000000  0.373587  0.160238
# parch         0.018322  0.082660 -0.150917  0.373587  1.000000  0.221539
# fare         -0.558629  0.244265  0.178739  0.160238  0.221539  1.000000
# body         -0.034642       NaN  0.058809 -0.099961  0.051099 -0.043110
# status       -0.337238  0.951574 -0.003067 -0.042736  0.070436  0.248781
# accomodation -0.713857  0.302250  0.289740 -0.009064  0.036806  0.507253
# gender_value -0.124617  0.528693 -0.063646  0.109609  0.213125  0.185523
# has family   -0.147393  0.201719 -0.128755  0.591077  0.549022  0.274895
#
#                   body    status  accomodation  gender_value  has family
# ...

# %%
import pandas as pd
import numpy as np
Location = "titanic3.xls"
df = pd.read_excel(Location)
df_nobody = df['body'].isnull()
df[df_nobody]
df_noboat = df['boat'].isnull()
df_live = df['survived']==1
df['status'] = np.where ((df_nobody & df_noboat),0,1)
df.loc[df['survived']>0,'status']=2
df.head()
df_steerage = df['cabin'].isnull()
df['accomodation'] = np.where ((df_steerage),0,1)
df.head()
def score_to_numeric(x):
    if x=='female':
        return 1
    if x=='male':
        return 0
df['gender_value']=df['sex'].apply(score_to_numeric)
df['has family'] = np.where((df['sibsp']<1) & (df['parch'] <1),0,1)
df.drop(['sibsp','parch','cabin','boat','body'], axis=1)
df.corr()
import statsmodels.formula.api as sm
result = sm.ols(formula='survived ~ pclass+gender_value+age', data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               survived   R-squared:                       0.369
# Model:                            OLS   Adj. R-squared:                  0.367
# Method:                 Least Squares   F-statistic:                     202.8
# Date:                Sat, 24 Feb 2018   Prob (F-statistic):          1.44e-103
# Time:                        13:12:39   Log-Likelihood:                -500.78
# No. Observations:                1046   AIC:                             1010.
# Df Residuals:                    1042   BIC:                             1029.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
import statsmodels.formula.api as sm
result = sm.ols(formula='survived ~ accomodation', data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               survived   R-squared:                       0.091
# Model:                            OLS   Adj. R-squared:                  0.091
# Method:                 Least Squares   F-statistic:                     131.4
# Date:                Sat, 24 Feb 2018   Prob (F-statistic):           4.69e-29
# Time:                        07:44:08   Log-Likelihood:                -849.83
# No. Observations:                1309   AIC:                             1704.
# Df Residuals:                    1307   BIC:                             1714.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# ...

# %%
import pandas as pd
import numpy as np
Location = "titanic3.xls"
df = pd.read_excel(Location)
df_nobody = df['body'].isnull()
df[df_nobody]
df_noboat = df['boat'].isnull()
df_live = df['survived']==1
df['status'] = np.where ((df_nobody & df_noboat),0,1)
df.loc[df['survived']>0,'status']=2
df.head()
df_steerage = df['cabin'].isnull()
df['accomodation'] = np.where ((df_steerage),0,1)
df.head()
def score_to_numeric(x):
    if x=='female':
        return 1
    if x=='male':
        return 0
df['gender_value']=df['sex'].apply(score_to_numeric)
df['has family'] = np.where((df['sibsp']<1) & (df['parch'] <1),0,1)
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body       status  accomodation  gender_value  \
# count  1308.000000  121.000000  1309.000000   1309.000000   1309.000000
# mean     33.295479  160.809917     0.863254      0.225363      0.355997
# std      51.758668   97.696922     0.939501      0.417981      0.478997
# ...

# %%
len(df[df['sex'] == 'female'])
# Out:
# 466

# %%
(df['embarked']=='S') & (df['age']>29)
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
# 5        True
# 6        True
# 7        True
# 8        True
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14       True
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20       True
# 21       True
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28       True
# 29      False
#         ...
# 1279    False
# 1280    False
# 1281    False
# 1282    False
# 1283    False
# 1284    False
# 1285     True
# 1286    False
# 1287     True
# 1288    False
# 1289    False
# 1290     True
# 1291    False
# 1292    False
# 1293    False
# 1294    False
# 1295    False
# 1296    False
# 1297    False
# 1298     True
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# 1303    False
# 1304    False
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# ...

# %%
len(df[(df['embarked']=='S') & (df['age']>29)])
# Out:
# 340

# %%
import pandas as pd
import numpy as np
Location = "titanic3.xls"
df = pd.read_excel(Location)
df_nobody = df['body'].isnull()
df[df_nobody]
df_noboat = df['boat'].isnull()
df_live = df['survived']==1
df['status'] = np.where ((df_nobody & df_noboat),0,1)
df.loc[df['survived']>0,'status']=2
df.head()
df_steerage = df['cabin'].isnull()
df['accomodation'] = np.where ((df_steerage),0,1)
df.head()
def score_to_numeric(x):
    if x=='female':
        return 1
    if x=='male':
        return 0
df['gender_value']=df['sex'].apply(score_to_numeric)
df['has family'] = np.where((df['sibsp']<1) & (df['parch'] <1),0,1)
## finding female survived
womanonship = len(df[df['sex'] == 'female'])
womanonshipsurvived = len(df[(df['sex']=='female') & (df['survived']==1)])
alive = len(df[df['survived']== 1]) 
def prob_womanonshipsurvived_alive(womanonshipsurvived,alive):
    return womanonshipsurvived/alive
prob_womanonshipsurvived_alive(womanonshipsurvived,alive)
# Out:
# 0.678

# %%
## finding hasfamily survived

family_alive = len(df[(df['has family']==1) & (df['survived']==1)])
prob_hasfamilysurvived=family_alive/alive
prob_hasfamilysurvived
# Out:
# 0.522

# %%
## finding cabin survived
cabin_alive = len(df[(df['accomodation']==1) & (df['survived']==1)])
prob_cabinsurvived=cabin_alive/alive
prob_cabinsurvived
# Out:
# 0.386

# %%
prob_survivedfemalehasfamilycabin=prob_womanonshipsurvived_alive(womanonshipsurvived,alive)*prob_hasfamilysurvived*prob_cabinsurvived
prob_survivedfemalehasfamilycabin
# Out:
# 0.13661157600000004

# %%
df.take(np.random.permutation(len(df))[:1000])
# Out:
#       pclass  survived                                               name  \
# 556        2         0                        Sharp, Mr. Percival James R
# 372        2         0                      Clarke, Mr. Charles Valentine
# 120        1         1                       Frauenthal, Mr. Isaac Gerald
# 911        3         0                     Kalvik, Mr. Johannes Halvorsen
# 713        3         0                                Charters, Mr. David
# 1308       3         0                                 Zimmerman, Mr. Leo
# 323        2         0                                Abelson, Mr. Samuel
# 1068       3         0                          Nysveen, Mr. Johan Hansen
# 561        2         0                          Sjostedt, Mr. Ernst Adolf
# 693        3         1                                Buckley, Mr. Daniel
# 875        3         0                       Ibrahim Shawah, Mr. Yousseff
# 62         1         0                        Chaffee, Mr. Herbert Fuller
# ...

# %%
survived
female
cabin
hasfamily

femalesurvived
cabinsurvived
hadfamilysurvived
femalesurvived/survived

# %%
## Naive Bayes Home work....family based probability

len(df[df['has family'] == 1])
# Out:
# 519

# %%
len(df[df['has family']==0])
# Out:
# 790

# %%
len(df[df['survived']== 0])
# Out:
# 809

# %%
died=len(df[df['survived']== 0])
family_died = len(df[(df['has family']==1) & (df['survived']==0)])
prob_hasfamilydied=family_died/died
prob_hasfamilydied
# Out:
# 0.3189122373300371

# %%
nofamily_died = len(df[(df['has family']==0) & (df['survived']==0)])
prob_nofamilydied=nofamily_died/died
prob_nofamilydied
# Out:
# 0.681087762669963

# %%
## Naive Bayes Home work....accomodation based probability
steerage_died = len(df[(df['accomodation']==0) & (df['survived']==0)])
prob_steeragedied=steerage_died/died
prob_steeragedied
# Out:
# 0.8739184177997528

# %%
cabin_died = len(df[(df['accomodation']==1) & (df['survived']==0)])
prob_cabindied=cabin_died/died
prob_cabindied
# Out:
# 0.1260815822002472

# %%
## Naive Bayes Home work....no family & no cabin based probability
steerage_died = len(df[(df['accomodation']==0) & (df['survived']==0)])
prob_steeragedied=steerage_died/died
prob_steeragedied
nofamily_died = len(df[(df['has family']==0) & (df['survived']==0)])
prob_nofamilydied=nofamily_died/died
prob_nofamilydied
prob_died_nocabinnofamily=prob_steeragedied*prob_nofamilydied
prob_died_nocabinnofamily
# Out:
# 0.5952151399353075

# %%
p_banana_long = 300/4500
p_banana_sweet = 450/650
p_banana_yellow = 450/800
p_long_banana =300/500
p_sweet_banana =450/500
p_yellow_banana =450/500
p_notbanana_long = 150/500
p_notbanana_sweet = 200/500
p_notbanana_yellow = 350/500

totalbananas = 500
totaloranges = 300
totalothers = 200

totallong = 450
totalsweet = 650
totalyellow = 800
prob_b_lsy =p_long_banana*p_yellow_banana*p_sweet_banana

# %%
def addnumbers(x,y):
    z = x+y
    return z
addnumbers(3,7)
# Out:
# 10

# %%
def addnumbers2(x,y):
    return x+y
def prob_a_b(a,b):
    return a/b

# %%
def prob_not(x,y):
    return 1-prob_a_b(x,y)

# %%
## probability of banana given that it is yellow
prob_a_b(yellowbanana,totalyellow)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-7b8ae0b1a28a> in <module>()
#       1 ## probability of banana given that it is yellow
# ----> 2 prob_a_b(yellowbanana,totalyellow)
#
# NameError: name 'yellowbanana' is not defined

# %%
##probability of yellow giver that it is banana
prob_a_b(yellowbanana,totalbanana)

##probability of not yellow given that it is banana
prob_a_b(totalbanana-yellowbanana,totalbanana)
